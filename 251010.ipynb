# %%
item = ["apple", "banana", "cat", "dog", "elephant"]
num = [1, 2, 3, 4, 5]
prices = [1000, 2500, 3000, 1500, 5000]

# %%
item
# Out:
# ['apple', 'banana', 'cat', 'dog', 'elephant']

# %%
num
# Out:
# [1, 2, 3, 4, 5]

# %%
prices
# Out:
# [1000, 2500, 3000, 1500, 5000]

# %%
for i in range(len(num)):
  num[i] = num[i] + 10

# %%
num
# Out:
# [11, 12, 13, 14, 15]

# %%
num[2]
# Out:
# 13

# %%
books = []

# %%
books.append("파이썬")
books.append("c")
books.append("자바")

# %%
books
# Out:
# ['파이썬', 'c', '자바']

# %%
books.insert(2,"go")

# %%
books
# Out:
# ['파이썬', 'c', 'go', '자바']

# %%
books.extend(["C++", "Pascal"])

# %%
books
# Out:
# ['파이썬', 'c', 'go', '자바', 'C++', 'Pascal']

# %%
books.pop()
# Out:
# 'Pascal'

# %%
books
# Out:
# ['파이썬', 'c', 'go', '자바', 'C++']

# %%
books.remove("c")

# %%
books
# Out:
# ['파이썬', 'go', '자바', 'C++']

# %%
books.clear()

# %%
books
# Out:
# []

# %%
num.reverse()

# %%
num
# Out:
# [15, 14, 13, 12, 11]

# %%
num.sort()

# %%
num
# Out:
# [11, 12, 13, 14, 15]

# %%
num.sort(reverse=True)

# %%
num
# Out:
# [15, 14, 13, 12, 11]

# %%
books = ['파이썬', 'c', 'go', '자바', 'C++', 'Pascal']

# %%
'자바' in books
# Out:
# True

# %%
'java' in books
# Out:
# False

# %%
books.index('자바')
# Out:
# 3

# %%
import random
random.choice(books)
# Out:
# 'Pascal'

# %%
max(prices)
# Out:
# 5000

# %%
sum(prices)
# Out:
# 13000

# %%
total = 0
for i in range(len(prices)):
  total = total + prices[i]

print(total)
# Out:
# 13000

# %%
dynasties = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종", "연산군",
    "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종", "숙종", "경종",
    "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]

# %%
for i in range(len(dynasties)):
  print(f"{i+1}대: {dynasties[i]}")
# Out:
# 1대: 태조
# 2대: 정종
# 3대: 태종
# 4대: 세종
# 5대: 문종
# 6대: 단종
# 7대: 세조
# 8대: 예종
# 9대: 성종
# 10대: 연산군
# 11대: 중종
# 12대: 인종
# 13대: 명종
# 14대: 선조
# 15대: 광해군
# 16대: 인조
# 17대: 효종
# 18대: 현종
# 19대: 숙종
# 20대: 경종
# 21대: 영조
# 22대: 정조
# 23대: 순조
# 24대: 헌종
# 25대: 철종
# 26대: 고종
# 27대: 순종

# %%
char1 = '\'한글\'\t사용법'

# %%
#print를 적용해야 특수문자가 먹힌다(작은 따옴표는 가능한듯)
print(char1)
# Out:
# '한글'	사용법

# %%
char2 = '메뉴얼'

# %%
print(char1+char2)
# Out:
# '한글'	사용법메뉴얼

# %%
s = 'hello'*5

# %%
s
# Out:
# 'hellohellohellohellohello'

# %%
'Python'.lower()
# Out:
# 'python'

# %%
ord('a')
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
a = input("데이터를 입력 ")
if a.isdigit():
  print("숫자입니다")
else:
  print("문자입니다")
# Out:
# 데이터를 입력 37
# 숫자입니다

# %%
#예외처리 부분까지 보완을 해야 프로그램이 완성된다. 나중에 완성해보기
answer = input("순번 또는 왕의 이름을 입력 ")
if answer.isdigit():
  i = int(answer)
  print(dynasties[i-1])
else:
  print(dynasties.index(answer)+1)
# Out:
# 순번 또는 왕의 이름을 입력 태조
# 1

# %%
t = [1,2,3,4,5]

# %%
#리스트는 수정이 가능하지만 튜플은 수정이 불가능하다. 전코드를 소괄호로 할 때 오류
t[1]=10

# %%
coffe = {'아메리카노':2000, '라떼':3000, '녹차':2500}

# %%
for k in coffe:
  print(coffe[k])
# Out:
# 2000
# 3000
# 2500

# %%
for k in coffe:
  print(k)
# Out:
# 아메리카노
# 라떼
# 녹차

# %%
for k,v in coffe.items():
  print(k, v)
# Out:
# 아메리카노 2000
# 라떼 3000
# 녹차 2500

# %%
#마지막실습: 점수의 합, 평균, 그리고 최대점수를 받은 이의 이름이 나오게 하라
score = {'홍길동':100, '이순신':90, '강감찬':80}

# %%
#총점
sum(score.values())
# Out:
# 270

# %%
#평균
sum(score.values()) / len(score)
# Out:
# 90.0

# %%
max(score.keys())
# Out:
# '홍길동'
